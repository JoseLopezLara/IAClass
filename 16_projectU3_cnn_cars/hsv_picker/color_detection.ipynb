# %%
# MAZDA ICONIC SP

import cv2
import os
import time


#TODO 1: Agregar la ruta del video a capturar
video_path = 'C:/git/IAClass/assets/projectU3/mazda_iconic_sp/v1-01.mp4'
output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/mazda_iconic_sp'

# Init video capture
cap = cv2.VideoCapture(video_path)
frame_count = 0 
capture_count = 0

# TODO 2: Definir los rangos de color HSV para cada color
#mazda_iconic_sp 
lower_red = (0, 97, 1)
upper_red = (179, 255, 233)


while True:
    # Capturar frame y condición de parado
    ret, frame = cap.read()
    if not ret:
        print('Video ended')
        break
    
    # Frame to hsv moden a create mask
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # TODO 3: Sumar las diferentes mascaras si es que tienen
    mask1 = cv2.inRange(hsv, lower_red, upper_red)
    #mask2 = cv2.inRange(hsv, lower_black, upper_black)
    # mask3 = cv2.inRange(hsv, lower_white, upper_white)
    # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
    # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
    #mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
    # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
    # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
    # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
    # TODO 4: Especificar la mascara final a utilizar 
    # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
    mask = mask1
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=0)
    mask = cv2.dilate(mask, None, iterations=0)
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        
        # Encontrar contorno mayor y obtener centro
        largest_contour = max(contours, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
            # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular (Esq superior izquierda y Esquina inferior derecha) 
            # y dibujar rectangulo a partir del centro y el radio
            
            # TODO 5: Definir el tamaño de recorder del rectángulo
            # top_left = list((int(x - radius), int(y - (radius  - 80))))
            # bottom_right = list((int(x + radius), int(y + (radius - 200))))
            top_left = list((int(x - radius), int(y - (radius))))
            bottom_right = list((int(x + radius), int(y + (radius))))
                      
            # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
            # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
            # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
            if frame_count % 1 == 0:
                
                # Normaliza recortes que salen de la pantalla
                if(top_left[0] < 0):
                    top_left[0] = 0 # Coordenada x
                if(top_left[1] < 0):
                    top_left[1] = 0 # Coordenada y
                
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
                if cropped_image.size > 0:
                    
                    capture_count += 1
                    
                    # Calcular el nuevo tamaño manteniendo la proporción
                    # target_width = 100
                    # (h, w) = cropped_image.shape[:2]
                    # aspect_ratio = w / h
                    # target_height = int(target_width / aspect_ratio)
                    resized_image = cv2.resize(cropped_image, (28, 21))
                    
                    filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.jpg")
                    cv2.imwrite(filename, resized_image)
                    # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
                    # cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    print(f"x: {x}, y: {y}, radius: {radius}")
                    print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
            frame_count += 1  
                  
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()

# %%
# # MAZDA ICONIC SP V2

# import cv2
# import os
# import time


# #TODO 1: Agregar la ruta del video a capturar
# video_path = 'C:/git/IAClass/assets/projectU3/mazda_iconic_sp/v1-02.mp4'
# output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/mazda_iconic_sp'

# # Init video capture
# cap = cv2.VideoCapture(video_path)
# frame_count = 0 
# capture_count = 0

# # TODO 2: Definir los rangos de color HSV para cada color
# #mazda_iconic_sp 
# lower_red1 = (168, 164, 14)
# upper_red1 = (177, 255, 105)

# lower_red2 = (132, 32, 67)
# upper_red2 = (177, 172, 143)

# while True:
#     # Capturar frame y condición de parado
#     ret, frame = cap.read()
#     if not ret:
#         print('Video ended')
#         break
    
#     # Frame to hsv moden a create mask
#     hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
#     # TODO 3: Sumar las diferentes mascaras si es que tienen
#     mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
#     mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    
#     #mask2 = cv2.inRange(hsv, lower_black, upper_black)
#     # mask3 = cv2.inRange(hsv, lower_white, upper_white)
#     # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
#     # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
#     mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
#     # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
#     # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
#     # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
#     # TODO 4: Especificar la mascara final a utilizar 
#     # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
#     mask = mask_mix_1_2
    
#     # Filtrar la máscara con operaciones morfológicas
#     mask = cv2.erode(mask, None, iterations=0)
#     mask = cv2.dilate(mask, None, iterations=0)
    
#     # Encontrar contornos en la máscara
#     contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if contours:
        
#         # Encontrar contorno mayor y obtener centro
#         largest_contour = max(contours, key=cv2.contourArea)
#         ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
#         # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
#         if radius > 10:
#             # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
#             # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
#             # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
#             # Calcular (Esq superior izquierda y Esquina inferior derecha) 
#             # y dibujar rectangulo a partir del centro y el radio
            
#             # TODO 5: Definir el tamaño de recorder del rectángulo
#             top_left = list((int(x - radius), int(y - (radius  - 70))))
#             bottom_right = list((int(x + radius), int(y + (radius - 70))))
#             # top_left = list((int(x - radius), int(y - (radius))))
#             # bottom_right = list((int(x + radius), int(y + (radius))))
                      
#             # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
#             # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
#             # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
#             if frame_count % 1 == 0:
                
#                 # Normaliza recortes que salen de la pantalla
#                 if(top_left[0] < 0):
#                     top_left[0] = 0 # Coordenada x
#                 if(top_left[1] < 0):
#                     top_left[1] = 0 # Coordenada y
                
#                 cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
#                 if cropped_image.size > 0:
                    
#                     capture_count += 1
                    
#                     # Calcular el nuevo tamaño manteniendo la proporción
#                     # target_width = 100
#                     # (h, w) = cropped_image.shape[:2]
#                     # aspect_ratio = w / h
#                     # target_height = int(target_width / aspect_ratio)
#                     resized_image = cv2.resize(cropped_image, (28, 21))
                    
#                     filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.jpg")
#                     cv2.imwrite(filename, resized_image)
#                     # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
#                     # cv2.imwrite(filename, resized_image)
#                     print(f"Imagen guardada: {filename}")
#                     print(f"x: {x}, y: {y}, radius: {radius}")
#                     print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
#             frame_count += 1  
                  
                    
#     # Mostrar el frame
#     cv2.imshow('Frame', frame)
#     cv2.imshow('Mask', mask)

#     # Salir si se presiona la tecla 'q'
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Liberar la captura y cerrar todas las ventanas
# cap.release()
# cv2.destroyAllWindows()

# %%
# FORD FIESTA ZETEC

import cv2
import os
import time


#TODO 1: Agregar la ruta del video a capturar
video_path = 'C:/git/IAClass/assets/projectU3/ford_fiesta_zetec/ford_fiesta_zetec.mp4'
output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/ford_fiesta_zetec'

# Init video capture
cap = cv2.VideoCapture(video_path)
frame_count = 0 
capture_count = 0

# TODO 2: Definir los rangos de color HSV para cada color
#mazda_iconic_sp 
lower_green = (0, 76, 1)
upper_green = (179, 255, 255)

while True:
    # Capturar frame y condición de parado
    ret, frame = cap.read()
    if not ret:
        print('Video ended')
        break
    
    # Frame to hsv moden a create mask
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # TODO 3: Sumar las diferentes mascaras si es que tienen
    mask1 = cv2.inRange(hsv, lower_green, upper_green)
    
    #mask2 = cv2.inRange(hsv, lower_black, upper_black)
    # mask3 = cv2.inRange(hsv, lower_white, upper_white)
    # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
    # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
    #mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
    # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
    # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
    # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
    # TODO 4: Especificar la mascara final a utilizar 
    # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
    mask = mask1
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=0)
    mask = cv2.dilate(mask, None, iterations=0)
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        
        # Encontrar contorno mayor y obtener centro
        largest_contour = max(contours, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
            # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular (Esq superior izquierda y Esquina inferior derecha) 
            # y dibujar rectangulo a partir del centro y el radio
            
            # TODO 5: Definir el tamaño de recorder del rectángulo
            # top_left = list((int(x - radius), int(y - (radius  - 70))))
            # bottom_right = list((int(x + radius), int(y + (radius - 70))))
            top_left = list((int(x - radius), int(y - (radius))))
            bottom_right = list((int(x + radius), int(y + (radius))))
                      
            # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
            # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
            # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
            if frame_count % 1 == 0:
                
                # Normaliza recortes que salen de la pantalla
                if(top_left[0] < 0):
                    top_left[0] = 0 # Coordenada x
                if(top_left[1] < 0):
                    top_left[1] = 0 # Coordenada y
                
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
                if cropped_image.size > 0:
                    
                    capture_count += 1
                    
                    # Calcular el nuevo tamaño manteniendo la proporción
                    # target_width = 100
                    # (h, w) = cropped_image.shape[:2]
                    # aspect_ratio = w / h
                    # target_height = int(target_width / aspect_ratio)
                    resized_image = cv2.resize(cropped_image, (28, 21))
                    
                    filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.jpg")
                    cv2.imwrite(filename, resized_image)
                    # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
                    # cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    print(f"x: {x}, y: {y}, radius: {radius}")
                    print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
            frame_count += 1  
                  
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()

# %%
# MINI COOPER

import cv2
import os
import time


#TODO 1: Agregar la ruta del video a capturar
video_path = 'C:/git/IAClass/assets/projectU3/mini_cooper_d/mini_cooper_d.mp4'
output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d'

# Init video capture
cap = cv2.VideoCapture(video_path)
frame_count = 0 
capture_count = 0

# TODO 2: Definir los rangos de color HSV para cada color
#mazda_iconic_sp 
lower_unicolor = (0, 0, 0)
upper_unicolor = (179, 255, 139)

while True:
    # Capturar frame y condición de parado
    ret, frame = cap.read()
    if not ret:
        print('Video ended')
        break
    
    # Frame to hsv moden a create mask
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # TODO 3: Sumar las diferentes mascaras si es que tienen
    mask1 = cv2.inRange(hsv, lower_unicolor, upper_unicolor)
    
    #mask2 = cv2.inRange(hsv, lower_black, upper_black)
    # mask3 = cv2.inRange(hsv, lower_white, upper_white)
    # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
    # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
    #mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
    # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
    # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
    # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
    # TODO 4: Especificar la mascara final a utilizar 
    # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
    mask = mask1
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=0)
    mask = cv2.dilate(mask, None, iterations=0)
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        
        # Encontrar contorno mayor y obtener centro
        largest_contour = max(contours, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
            # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular (Esq superior izquierda y Esquina inferior derecha) 
            # y dibujar rectangulo a partir del centro y el radio
            
            # TODO 5: Definir el tamaño de recorder del rectángulo
            top_left = list((int(x - (radius - 180)), int(y - (radius  - 250))))
            bottom_right = list((int(x + (radius - 180)), int(y + (radius - 620))))
            # top_left = list((int(x - radius), int(y - (radius))))
            # bottom_right = list((int(x + radius), int(y + (radius))))
                      
            # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
            # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
            # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
            if frame_count % 1 == 0:
                
                # Normaliza recortes que salen de la pantalla
                if(top_left[0] < 0):
                    top_left[0] = 0 # Coordenada x
                if(top_left[1] < 0):
                    top_left[1] = 0 # Coordenada y
                
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
                if cropped_image.size > 0:
                    
                    capture_count += 1
                    
                    # Calcular el nuevo tamaño manteniendo la proporción
                    # target_width = 100
                    # (h, w) = cropped_image.shape[:2]
                    # aspect_ratio = w / h
                    # target_height = int(target_width / aspect_ratio)
                    
                    
                    
                    if(frame_count % 2 == 0):
                        resized_image = cv2.resize(cropped_image, (28, 21))
                        
                        cv2.imwrite(filename, resized_image)
                        filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.jpg")
                        
                        
                    # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
                    # cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    print(f"x: {x}, y: {y}, radius: {radius}")
                    print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
            frame_count += 1  
                  
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()
# Out:
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num1_frame_Num0_1733976818.3547807.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num1_frame_Num0_1733976818.3547807.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3_frame_Num2_1733976818.4929802.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3_frame_Num2_1733976818.4929802.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num5_frame_Num4_1733976818.5114033.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num5_frame_Num4_1733976818.5114033.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num7_frame_Num6_1733976818.5282953.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num7_frame_Num6_1733976818.5282953.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num9_frame_Num8_1733976818.5477953.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num9_frame_Num8_1733976818.5477953.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num11_frame_Num10_1733976818.5662644.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num11_frame_Num10_1733976818.5662644.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num13_frame_Num12_1733976818.584342.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num13_frame_Num12_1733976818.584342.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num15_frame_Num14_1733976818.601904.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num15_frame_Num14_1733976818.601904.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num17_frame_Num16_1733976818.619474.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num17_frame_Num16_1733976818.619474.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num19_frame_Num18_1733976818.6375303.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num19_frame_Num18_1733976818.6375303.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num21_frame_Num20_1733976818.6559658.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num21_frame_Num20_1733976818.6559658.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num23_frame_Num22_1733976818.6731575.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num23_frame_Num22_1733976818.6731575.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num25_frame_Num24_1733976818.6896749.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num25_frame_Num24_1733976818.6896749.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num27_frame_Num26_1733976818.7082582.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num27_frame_Num26_1733976818.7082582.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num29_frame_Num28_1733976818.7254276.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num29_frame_Num28_1733976818.7254276.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num31_frame_Num30_1733976818.7418034.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num31_frame_Num30_1733976818.7418034.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num33_frame_Num32_1733976818.758697.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num33_frame_Num32_1733976818.758697.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num35_frame_Num34_1733976818.7749088.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num35_frame_Num34_1733976818.7749088.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num37_frame_Num36_1733976818.793468.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num37_frame_Num36_1733976818.793468.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num39_frame_Num38_1733976818.811008.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num39_frame_Num38_1733976818.811008.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num41_frame_Num40_1733976818.8275607.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num41_frame_Num40_1733976818.8275607.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num43_frame_Num42_1733976818.8441296.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num43_frame_Num42_1733976818.8441296.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num45_frame_Num44_1733976818.861223.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num45_frame_Num44_1733976818.861223.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num47_frame_Num46_1733976818.879898.jpg
# x: 639.5, y: 533.0, radius: 643.54052734375
# top_left: [175, 139], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_
jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3227_frame_Num3226_1733976849.325713.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3227_frame_Num3226_1733976849.325713.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3229_frame_Num3228_1733976849.3437793.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3229_frame_Num3228_1733976849.3437793.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3231_frame_Num3230_1733976849.360798.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3231_frame_Num3230_1733976849.360798.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3233_frame_Num3232_1733976849.3778598.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3233_frame_Num3232_1733976849.3778598.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3235_frame_Num3234_1733976849.3938954.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3235_frame_Num3234_1733976849.3938954.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3237_frame_Num3236_1733976849.4114132.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3237_frame_Num3236_1733976849.4114132.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3239_frame_Num3238_1733976849.4302099.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3239_frame_Num3238_1733976849.4302099.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3241_frame_Num3240_1733976849.448991.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3241_frame_Num3240_1733976849.448991.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3243_frame_Num3242_1733976849.466114.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3243_frame_Num3242_1733976849.466114.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3245_frame_Num3244_1733976849.5008616.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Imagen guardada: C:/git/IAClass/16_projectU3_cnn_cars/captures/mini_cooper_d\capture_Num3245_frame_Num3244_1733976849.5008616.jpg
# x: 639.5, y: 532.5, radius: 643.5966796875
# top_left: [175, 138], bottom_right: [1103, 556]
# Video ended

# %%
# ROVER_P6

import cv2
import os
import time


#TODO 1: Agregar la ruta del video a capturar
video_path = 'C:/git/IAClass/assets/projectU3/rover_p6_3500s/rover_p6_3500s.mp4'
output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/rover_p6_3500s'

# Init video capture
cap = cv2.VideoCapture(video_path)
frame_count = 0 
capture_count = 0

# TODO 2: Definir los rangos de color HSV para cada color
#mazda_iconic_sp 
lower_unicolor = (0, 0, 0)
upper_unicolor = (180, 255, 255)

while True:
    # Capturar frame y condición de parado
    ret, frame = cap.read()
    if not ret:
        print('Video ended')
        break
    
    # Frame to hsv moden a create mask
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # TODO 3: Sumar las diferentes mascaras si es que tienen
    mask1 = cv2.inRange(hsv, lower_unicolor, upper_unicolor)
    
    #mask2 = cv2.inRange(hsv, lower_black, upper_black)
    # mask3 = cv2.inRange(hsv, lower_white, upper_white)
    # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
    # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
    #mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
    # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
    # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
    # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
    # TODO 4: Especificar la mascara final a utilizar 
    # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
    mask = mask1
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=0)
    mask = cv2.dilate(mask, None, iterations=0)
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        
        # Encontrar contorno mayor y obtener centro
        largest_contour = max(contours, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
            # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular (Esq superior izquierda y Esquina inferior derecha) 
            # y dibujar rectangulo a partir del centro y el radio
            
            # TODO 5: Definir el tamaño de recorder del rectángulo
            top_left = list((int(x - (radius )), int(y - (radius  - 280))))
            bottom_right = list((int(x + (radius - 65)), int(y + (radius - 220))))
            # top_left = list((int(x - radius), int(y - (radius))))
            # bottom_right = list((int(x + radius), int(y + (radius))))
                      
            # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
            # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
            # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
            if frame_count % 1 == 0:
                
                # Normaliza recortes que salen de la pantalla
                if(top_left[0] < 0):
                    top_left[0] = 0 # Coordenada x
                if(top_left[1] < 0):
                    top_left[1] = 0 # Coordenada y
                
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
                if cropped_image.size > 0:
                    
                    capture_count += 1
                    
                    # Calcular el nuevo tamaño manteniendo la proporción
                    # target_width = 100
                    # (h, w) = cropped_image.shape[:2]
                    # aspect_ratio = w / h
                    # target_height = int(target_width / aspect_ratio)
                    resized_image = cv2.resize(cropped_image, (28, 21))
                    
                    filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.jpg")
                    cv2.imwrite(filename, resized_image)
                    # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
                    # cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    print(f"x: {x}, y: {y}, radius: {radius}")
                    print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
            frame_count += 1  
                  
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()

# %%
# volkswagen_up

import cv2
import os
import time


#TODO 1: Agregar la ruta del video a capturar
video_path = 'C:/git/IAClass/assets/projectU3/volkswagen_up/volkswagen_up.mp4'
output_directory = 'C:/git/IAClass/16_projectU3_cnn_cars/captures/volkswagen_up'

# Init video capture
cap = cv2.VideoCapture(video_path)
frame_count = 0 
capture_count = 0

# TODO 2: Definir los rangos de color HSV para cada color
#mazda_iconic_sp 
lower_unicolor = (0, 0, 0)
upper_unicolor = (179, 255, 139)

while True:
    # Capturar frame y condición de parado
    ret, frame = cap.read()
    if not ret:
        print('Video ended')
        break
    
    # Frame to hsv moden a create mask
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # TODO 3: Sumar las diferentes mascaras si es que tienen
    mask1 = cv2.inRange(hsv, lower_unicolor, upper_unicolor)
    
    #mask2 = cv2.inRange(hsv, lower_black, upper_black)
    # mask3 = cv2.inRange(hsv, lower_white, upper_white)
    # mask4 = cv2.inRange(hsv, lower_shadows, upper_shadows)
    # mask5 = cv2.inRange(hsv, lower_orange_dark, upper_orange_dark)
    #mask_mix_1_2 = cv2.bitwise_or(mask1, mask2)
    # mask_mix_1_2_3= cv2.bitwise_or(mask_mix_1_2, mask3)
    # mask_mix_1_2_3_4= cv2.bitwise_or(mask_mix_1_2_3, mask4)
    # mask_mix_1_2_3_4_5= cv2.bitwise_or(mask_mix_1_2_3_4, mask5)
    
    # TODO 4: Especificar la mascara final a utilizar 
    # TODO 4 (Ya sea una combinación de varias máscaras o una sola máscara)
    mask = mask1
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=0)
    mask = cv2.dilate(mask, None, iterations=0)
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        
        # Encontrar contorno mayor y obtener centro
        largest_contour = max(contours, key=cv2.contourArea)
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            # ! TODO 6: COMENTAR ESTAS DOS LINEAS PARA GENERERA DATASEF FINAL
            # cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            # cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular (Esq superior izquierda y Esquina inferior derecha) 
            # y dibujar rectangulo a partir del centro y el radio
            
            # TODO 5: Definir el tamaño de recorder del rectángulo
            top_left = list((int(x - (radius - 215)), int(y - (radius  - 250))))
            bottom_right = list((int(x + (radius - 250)), int(y + (radius - 615))))
            # top_left = list((int(x - radius), int(y - (radius))))
            # bottom_right = list((int(x + radius), int(y + (radius))))
                      
            # ! TODO 7: COMENTAR ESTA LINEA PARA GENERERA DATASEF FINAL
            # cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 1)
            
            # Tomar y guardar captura cada "X" frames a partir de la región del rectángulo
            if frame_count % 1 == 0:
                
                # Normaliza recortes que salen de la pantalla
                if(top_left[0] < 0):
                    top_left[0] = 0 # Coordenada x
                if(top_left[1] < 0):
                    top_left[1] = 0 # Coordenada y
                
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
                
                if cropped_image.size > 0:
                    
                    capture_count += 1
                    
                    # Calcular el nuevo tamaño manteniendo la proporción
                    # target_width = 100
                    # (h, w) = cropped_image.shape[:2]
                    # aspect_ratio = w / h
                    # target_height = int(target_width / aspect_ratio)
                    resized_image = cv2.resize(cropped_image, (28, 21))
                    
                    filename = os.path.join(output_directory, f"capture_Num{capture_count}_frame_Num{frame_count}_{time.time()}.png")
                    cv2.imwrite(filename, resized_image)
                    # filename = os.path.join(output_directory, f"capture_Num{capture_count}_v2_frame_Num{frame_count}_{time.time()}.jpg")
                    # cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    print(f"x: {x}, y: {y}, radius: {radius}")
                    print(f"top_left: {top_left}, bottom_right: {bottom_right}")
                    
            frame_count += 1  
                  
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()
