# %%
import cv2
import numpy as np
import os

video_path = 'C:/git/IAClass/assets/color_detection/globo_rojo_corto.mp4'
output_directory = 'C:/git/IAClass/02_follow_using_color_detection/captures/'

# Iniciar la captura de video desde la cámara
cap = cv2.VideoCapture(video_path)

# Definir el rango de color que quieres rastrear en el espacio de color HSV
# Rango inferior del rojo
lower_red1 = (0, 100, 100)     
upper_red1 = (10, 255, 255)    
# Rango superior del rojo
lower_red2 = (170, 100, 100)   
upper_red2 = (180, 255, 255)  

# Contador de frames para nombrar las imágenes
frame_count = 0   

while True:
    # Capturar frame por frame
    ret, frame = cap.read()
    if not ret:
        break
    
    # Convertir el frame de BGR a HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
    # Crear una máscara que detecte solo el color rojo
    # Crear las dos máscaras para el rango inferior y superior del rojo
    mask1 = cv2.inRange(hsv, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv, lower_red2, upper_red2)
    mask = cv2.bitwise_or(mask1, mask2)
    
    # Filtrar la máscara con operaciones morfológicas
    mask = cv2.erode(mask, None, iterations=2)
    mask = cv2.dilate(mask, None, iterations=2)
    
    
    # Encontrar contornos en la máscara
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Si se encuentra al menos un contorno, seguir el objeto
    if contours:
        # Tomar el contorno más grande
        largest_contour = max(contours, key=cv2.contourArea)
        
        # Encontrar el centro del contorno usando un círculo mínimo que lo rodee
        ((x, y), radius) = cv2.minEnclosingCircle(largest_contour)
        
        # Dibujar el círculo y el centro en el frame original si el radio es mayor que un umbral
        if radius > 10:
            cv2.circle(frame, (int(x), int(y)), int(radius), (0, 255, 255), 2)
            cv2.circle(frame, (int(x), int(y)), 5, (0, 255, 255), -1)
            
            # Calcular las coordenadas del rectángulo a partir del centro y el radio
            top_left = (int(x - radius), int(y - radius))  # Esquina superior izquierda
            bottom_right = (int(x + radius), int(y + radius))  # Esquina inferior derecha
            
            # Dibujar el rectángulo verde que rodea al segmento
            cv2.rectangle(frame, top_left, bottom_right, (0, 255, 0), 2)  # Color verde (0, 255, 0)
            
            #condicional para tomar efectuar recorte cada 15 frames:
            if frame_count % 15 == 0:
                # Recortar la región del rectángulo del frame original
                cropped_image = frame[top_left[1]:bottom_right[1], top_left[0]:bottom_right[0]]
            
                # Guardar la imagen recortada si no está vacía
                if cropped_image.size > 0:
                    # Redimensionar la imagen a 180x180 píxeles
                    resized_image = cv2.resize(cropped_image, (100, 100))
                    
                    filename = os.path.join(output_directory, f"frame_{frame_count}.png")
                    cv2.imwrite(filename, resized_image)
                    print(f"Imagen guardada: {filename}")
                    
            frame_count += 1        
                    
    # Mostrar el frame
    cv2.imshow('Frame', frame)
    cv2.imshow('Mask', mask)

    # Salir si se presiona la tecla 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Liberar la captura y cerrar todas las ventanas
cap.release()
cv2.destroyAllWindows()
# Out:
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_0.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_15.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_30.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_45.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_60.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_75.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_90.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_105.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_120.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_135.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_150.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_165.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_180.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_195.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_210.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_225.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_240.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_255.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_270.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_285.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_300.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_315.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_330.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_345.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_360.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_375.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_390.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_405.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_420.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_435.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_450.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_465.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_480.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_495.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_510.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_525.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_540.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_555.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_570.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_585.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_615.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_630.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_645.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_660.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_675.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_690.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_720.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_735.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_750.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_765.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_780.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_795.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_810.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_825.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_840.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_855.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_870.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_885.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_900.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_915.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_930.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_945.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_960.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_975.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_990.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1005.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1020.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1065.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1080.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1095.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1110.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1125.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1140.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1155.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1170.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1185.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1200.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1215.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1230.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1245.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1260.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1275.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1290.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1305.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1320.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1335.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1350.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1365.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1395.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1425.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1440.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1515.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1560.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1575.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1635.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1650.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1665.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1680.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1695.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1710.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1725.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1740.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1755.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1770.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1785.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1800.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1815.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1830.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1845.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1860.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1875.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1890.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1905.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1920.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1935.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1950.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1965.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1980.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_1995.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2010.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2025.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2040.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2055.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2070.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2085.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2100.png
# Imagen guardada: C:/git/IAClass/02_follow_using_color_detection/captures/frame_2115.png
